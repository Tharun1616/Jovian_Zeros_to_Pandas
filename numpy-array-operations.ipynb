# %% [markdown]
# # 5 Numpy Functions you should know
#
#
# ###  Numpy
#
# Numpy is a module for Python,which stands for "Numerical Python".It is a python package for scientific computing that provides high-performance multi-dimensional array objects.
#
# - numpy.argmax()
# - numpy.isnan()
# - numpy.vstack()
# - numpy.insert()
# - numpy.repeat()
#
# The recommended way to run this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on mybinder.org, a free online service for running Jupyter notebooks.

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project='numpy-array-operations')
# Out:
# [jovian] Attempting to save notebook..

# %% [markdown]
# Let's begin by importing Numpy and listing out the functions covered in this notebook.

# %%
import numpy as np

# %%
# List of functions explained 
function1 = np.argmax
function2 = np.isnan
function3 = np.vstack
function4 = np.hstack
function5 = np.repeat

# %% [markdown]
# ## Function 1 - np.argmax()
#
# This function returns the indices of the maximum values along an axis

# %%
# Example 1 - working 
arr1 = np.array([[1,2,3],[4,5,6]])
print("index of max value is:",np.argmax(arr1))
# Out:
# index of max value is: 5

# %% [markdown]
# We can obtain the index of the maximum value in the array

# %%
# Example 2 - working
arr2 = np.array([[7,8,9],
                 [4,5,6],
                 [10,3,5]])
print("index of max value along 0 axis is:",np.argmax(arr2,axis=0))
print("index of max value along 1 axis is:",np.argmax(arr2,axis=1))
# Out:
# index of max value along 0 axis is: [2 0 0]
# index of max value along 1 axis is: [2 2 0]

# %% [markdown]
# We can obtain the index of the maximum value in the array on x and y axis

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr3 = np.array([1,2,3])
np.argmax(arr3,axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_38/3563833654.py in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
#       2 arr3 = np.array([1,2,3])
# ----> 3 np.argmax(arr3,axis=1)
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py in argmax(a, axis, out)
#    1191
#    1192     """
# -> 1193     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1194
#    1195
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %% [markdown]
# Here we are check the for max value index in array along y axis which is not there.

# %% [markdown]
# This function can be very useful when we wanted to know the index of max value in matrix with n dimensions and also in reinforcement learning tasks.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/numpy-array-operations
# 'https://jovian.ml/aakashns/numpy-array-operations'

# %% [markdown]
# ## Function 2 - np.isnan()
#
# This function is used to know  if there is NAN in dataset.

# %%
# Example 1 - working
arr1 = np.array([[1,9,8],[3,2,1],[6,7,4]])
np.isnan(arr1)
# Out:
# array([[False, False, False],
#        [False, False, False],
#        [False, False, False]])

# %% [markdown]
# Here we can see all false because there is no nan value

# %%
# Example 2 - working
arr2 = np.array([[1,9,7],[0,2,1],[7,1,4.]])
arr2[0,1] = np.nan
arr2[2,2] = np.nan
np.isnan(arr2)
# Out:
# array([[False,  True, False],
#        [False, False, False],
#        [False, False,  True]])

# %% [markdown]
# After adding the nan now we can see the true as there are nan values

# %%
# Example 3 - breaking (to illustrate when it breaks)
np.isnan(np.array([[np.nan, 8],
                   [6, 11]], 
                  dtype=object))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_38/918297650.py in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
# ----> 2 np.isnan(np.array([[np.nan, 8],
#       3                    [6, 11]],
#       4                   dtype=object))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# A NAN Values can't be inserted in the type of object

# %% [markdown]
# Used to find the NaN values in the dataset

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/numpy-array-operations
# 'https://jovian.ml/aakashns/numpy-array-operations'

# %% [markdown]
# ## Function 3 - np.vstack()
#
# Concatenates the arrays along columns(Vertically)

# %%
# Example 1 - working
arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([[5,6],[7,8]])
np.vstack((arr1,arr2))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %% [markdown]
# Concatenates the arr1 and arr2.

# %%
# Example 2 - working
lis1 = [1,2,3,4]
lis2 = [6,7,8,9]
np.vstack((lis1,lis2))
# Out:
# array([[1, 2, 3, 4],
#        [6, 7, 8, 9]])

# %% [markdown]
# Concatenates the two lists lis1 and lis2 vertically into a single array

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([[5,6,2],[7,8,9]])
np.vstack((arr1,arr2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_38/1698311909.py in <module>
#       2 arr1 = np.array([[1,2],[3,4]])
#       3 arr2 = np.array([[5,6,2],[7,8,9]])
# ----> 4 np.vstack((arr1,arr2))
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 2 and the array at index 1 has size 3

# %% [markdown]
# The no of values in the both the arrays are different to concatenate it should match

# %% [markdown]
# Used to Concatenate the data vertically

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/numpy-array-operations
# 'https://jovian.ml/aakashns/numpy-array-operations'

# %% [markdown]
# ## Function 4 - np.insert()
#
# this will be used to insert values.

# %%
# Example 1 - working
arr1 = np.array([[1,2,3],[4,5,6]])
np.insert(arr1,2,[10,12])
# Out:
# array([ 1,  2, 10, 12,  3,  4,  5,  6])

# %% [markdown]
# List of 10,12 is inserted at pos 2

# %%
# Example 2 - working
arr2 = np.array([[1,2,3],[4,5,6]])
np.insert(arr2,2,[10,12,14],axis=0)
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [10, 12, 14]])

# %% [markdown]
# List of 10,12,14 is inserted at row 2 as we gave the axis=0

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr2 = np.array([[1,2,3],[4,5,6]])
np.insert(arr2,2,[10,12],axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_38/3544564072.py in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
#       2 arr2 = np.array([[1,2,3],[4,5,6]])
# ----> 3 np.insert(arr2,2,[10,12],axis=0)
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py in insert(arr, obj, values, axis)
#    4650         new[tuple(slobj)] = arr[tuple(slobj)]
#    4651         slobj[axis] = slice(index, index+numnew)
# -> 4652         new[tuple(slobj)] = values
#    4653         slobj[axis] = slice(index+numnew, None)
#    4654         slobj2 = [slice(None)] * ndim
#
# ValueError: could not broadcast input array from shape (1,2) into shape (1,3)

# %% [markdown]
# Values can't be inserted as the shape is not same to insert or avoid this error we need to give the same shape(1,3)

# %% [markdown]
# Very helpful in inserting values

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/numpy-array-operations
# 'https://jovian.ml/aakashns/numpy-array-operations'

# %% [markdown]
# ## Function 5 - np.repeat()
#
# function repeats the elements of an array

# %%
# Example 1 - working
np.repeat(3,5)
# Out:
# array([3, 3, 3, 3, 3])

# %% [markdown]
# it will repeat the value 3 five times

# %%
# Example 2 - working
np.repeat(a=[8,9],repeats=3)
# Out:
# array([8, 8, 8, 9, 9, 9])

# %% [markdown]
# to repeat the multiple values n times (here we are repeating 8,9 values 3 times)

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr1 = np.array([[1,4],[7,6]])
rep1 = np.repeat(a=arr1,repeats=2,axis=0)
print("Repeating values Downward using axis 0;",rep1)
rep2 = np.repeat(a=3,repeats=5,axis=1)
print(rep2)
# Out:
# Repeating values Downward using axis 0; [[1 4]
#  [1 4]
#  [7 6]
#  [7 6]]
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_38/2845534215.py in <module>
#       3 rep1 = np.repeat(a=arr1,repeats=2,axis=0)
#       4 print("Repeating values Downward using axis 0;",rep1)
# ----> 5 rep2 = np.repeat(a=3,repeats=5,axis=1)
#       6 print(rep2)
#
# <__array_function__ internals> in repeat(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py in repeat(a, repeats, axis)
#     478
#     479     """
# --> 480     return _wrapfunc(a, 'repeat', repeats, axis=axis)
#     481
#     482
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      53     bound = getattr(obj, method, None)
#      54     if bound is None:
# ---> 55         return _wrapit(obj, method, *args, **kwds)
#      56
#      57     try:
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      42     except AttributeError:
#      43         wrap = None
# ---> 44     result = getattr(asarray(obj), method)(*args, **kwds)
#      45     if wrap:
#      46         if not isinstance(result, mu.ndarray):
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %% [markdown]
# As in the rep2 we gave the axis as 1 we get the error as out of bounds

# %% [markdown]
# Very helpful in repeating values and also duplicating the matrix or duplicate rows.

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "ganeshtharun98/numpy-array-operations" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/ganeshtharun98/numpy-array-operations
# 'https://jovian.com/ganeshtharun98/numpy-array-operations'

# %% [markdown]
# ## Conclusion
#
# Summarize what was covered in this notebook, and where to go next

# %% [markdown]
# ## Reference Links
# Provide links to your references and other interesting articles about Numpy arrays:
# * Numpy official tutorial : https://numpy.org/doc/stable/user/quickstart.html
# * ...

# %%
jovian.commit()
